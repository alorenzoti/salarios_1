# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
salaries = pd.read_csv('data/salaries_data.csv')

# %%
salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %%
test = pd.read_csv('data/testeo.csv')

# %%
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   employee_residence  remote_ratio company_location company_size
# 0                 JP             0               JP            S
# 1                 US           100               US            L
# 2                 US           100               US            L
# 3                 CN             0               CN            M
# 4                 IN           100               IN            L

# %%
len(salaries.columns)==len(test.columns)
# Out:
# False

# %%
salaries.drop(columns=salaries[['salary', 'salary_currency']], axis=1, inplace=True)

# %%
len(salaries.columns)
# Out:
# 9

# %%
salaries.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
len(test.columns)
# Out:
# 8

# %%
from pycaret.regression import *
s= setup(salaries, target = 'salary_in_usd')
# Out:
# <style type="text/css">
# #T_99bf7_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99bf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99bf7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99bf7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99bf7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99bf7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_99bf7_row0_col1" class="data row0 col1" >4226</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99bf7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99bf7_row1_col1" class="data row1 col1" >salary_in_usd</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99bf7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_99bf7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99bf7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_99bf7_row3_col1" class="data row3 col1" >(500, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99bf7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_99bf7_row4_col1" class="data row4 col1" >(500, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99bf7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_99bf7_row5_col1" class="data row5 col1" >(350, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99bf7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_99bf7_row6_col1" class="data row6 col1" >(150, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99bf7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_99bf7_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99bf7_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_99bf7_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99bf7_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_99bf7_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99bf7_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_99bf7_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99bf7_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_99bf7_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99bf7_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_99bf7_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99bf7_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_99bf7_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99bf7_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_99bf7_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99bf7_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_99bf7_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99bf7_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_99bf7_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99bf7_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_99bf7_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99bf7_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_99bf7_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99bf7_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_99bf7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99bf7_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_99bf7_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_99bf7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99bf7_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_99bf7_row21_col1" class="data row21 col1" >9cf2</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_783e6 th {
#   text-align: left;
# }
# #T_783e6_row0_col0, #T_783e6_row0_col1, #T_783e6_row0_col2, #T_783e6_row0_col5, #T_783e6_row0_col6, #T_783e6_row1_col0, #T_783e6_row1_col1, #T_783e6_row1_col2, #T_783e6_row1_col3, #T_783e6_row1_col4, #T_783e6_row1_col5, #T_783e6_row1_col6, #T_783e6_row2_col0, #T_783e6_row2_col1, #T_783e6_row2_col2, #T_783e6_row2_col3, #T_783e6_row2_col4, #T_783e6_row2_col5, #T_783e6_row2_col6, #T_783e6_row3_col0, #T_783e6_row3_col1, #T_783e6_row3_col2, #T_783e6_row3_col3, #T_783e6_row3_col4, #T_783e6_row3_col5, #T_783e6_row3_col6, #T_783e6_row4_col0, #T_783e6_row4_col1, #T_783e6_row4_col2, #T_783e6_row4_col3, #T_783e6_row4_col4, #T_783e6_row4_col5, #T_783e6_row4_col6, #T_783e6_row5_col0, #T_783e6_row5_col2, #T_783e6_row5_col3, #T_783e6_row5_col4, #T_783e6_row5_col5, #T_783e6_row5_col6, #T_783e6_row6_col0, #T_783e6_row6_col1, #T_783e6_row6_col2, #T_783e6_row6_col3, #T_783e6_row6_col4, #T_783e6_row6_col6, #T_783e6_row7_col0, #T_783e6_row7_col1, #T_783e6_row7_col2, #T_783e6_row7_col3, #T_783e6_row7_col4, #T_783e6_row7_col5, #T_783e6_row7_col6, #T_783e6_row8_col0, #T_783e6_row8_col1, #T_783e6_row8_col2, #T_783e6_row8_col3, #T_783e6_row8_col4, #T_783e6_row8_col5, #T_783e6_row8_col6, #T_783e6_row9_col0, #T_783e6_row9_col1, #T_783e6_row9_col2, #T_783e6_row9_col3, #T_783e6_row9_col4, #T_783e6_row9_col5, #T_783e6_row9_col6, #T_783e6_row10_col0, #T_783e6_row10_col1, #T_783e6_row10_col2, #T_783e6_row10_col3, #T_783e6_row10_col4, #T_783e6_row10_col5, #T_783e6_row10_col6, #T_783e6_row11_col0, #T_783e6_row11_col1, #T_783e6_row11_col2, #T_783e6_row11_col3, #T_783e6_row11_col4, #T_783e6_row11_col5, #T_783e6_row11_col6, #T_783e6_row12_col0, #T_783e6_row12_col1, #T_783e6_row12_col3, #T_783e6_row12_col4, #T_783e6_row12_col5, #T_783e6_row13_col0, #T_783e6_row13_col1, #T_783e6_row13_col2, #T_783e6_row13_col3, #T_783e6_row13_col4, #T_783e6_row13_col5, #T_783e6_row13_col6, #T_783e6_row14_col0, #T_783e6_row14_col1, #T_783e6_row14_col2, #T_783e6_row14_col3, #T_783e6_row14_col4, #T_783e6_row14_col5, #T_783e6_row14_col6, #T_783e6_row15_col0, #T_783e6_row15_col1, #T_783e6_row15_col2, #T_783e6_row15_col3, #T_783e6_row15_col4, #T_783e6_row15_col5, #T_783e6_row15_col6, #T_783e6_row16_col0, #T_783e6_row16_col1, #T_783e6_row16_col2, #T_783e6_row16_col3, #T_783e6_row16_col4, #T_783e6_row16_col5, #T_783e6_row16_col6, #T_783e6_row17_col0, #T_783e6_row17_col1, #T_783e6_row17_col2, #T_783e6_row17_col3, #T_783e6_row17_col4, #T_783e6_row17_col5, #T_783e6_row17_col6, #T_783e6_row18_col0, #T_783e6_row18_col1, #T_783e6_row18_col2, #T_783e6_row18_col3, #T_783e6_row18_col4, #T_783e6_row18_col5, #T_783e6_row18_col6 {
#   text-align: left;
# }
# #T_783e6_row0_col3, #T_783e6_row0_col4, #T_783e6_row5_col1, #T_783e6_row6_col5, #T_783e6_row12_col2, #T_783e6_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_783e6_row0_col7, #T_783e6_row1_col7, #T_783e6_row2_col7, #T_783e6_row4_col7, #T_783e6_row5_col7, #T_783e6_row6_col7, #T_783e6_row7_col7, #T_783e6_row8_col7, #T_783e6_row9_col7, #T_783e6_row10_col7, #T_783e6_row11_col7, #T_783e6_row12_col7, #T_783e6_row13_col7, #T_783e6_row14_col7, #T_783e6_row15_col7, #T_783e6_row16_col7, #T_783e6_row17_col7, #T_783e6_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_783e6_row3_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_783e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_783e6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_783e6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_783e6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_783e6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_783e6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_783e6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_783e6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_783e6_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_783e6_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_783e6_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_783e6_row0_col1" class="data row0 col1" >38427.4640</td>
#       <td id="T_783e6_row0_col2" class="data row0 col2" >3279161262.4543</td>
#       <td id="T_783e6_row0_col3" class="data row0 col3" >53966.6451</td>
#       <td id="T_783e6_row0_col4" class="data row0 col4" >0.4142</td>
#       <td id="T_783e6_row0_col5" class="data row0 col5" >0.5864</td>
#       <td id="T_783e6_row0_col6" class="data row0 col6" >0.7112</td>
#       <td id="T_783e6_row0_col7" class="data row0 col7" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_783e6_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_783e6_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_783e6_row1_col1" class="data row1 col1" >38500.4985</td>
#       <td id="T_783e6_row1_col2" class="data row1 col2" >3324340231.4256</td>
#       <td id="T_783e6_row1_col3" class="data row1 col3" >54232.5653</td>
#       <td id="T_783e6_row1_col4" class="data row1 col4" >0.4080</td>
#       <td id="T_783e6_row1_col5" class="data row1 col5" >0.5838</td>
#       <td id="T_783e6_row1_col6" class="data row1 col6" >0.7098</td>
#       <td id="T_783e6_row1_col7" class="data row1 col7" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_783e6_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_783e6_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_783e6_row2_col1" class="data row2 col1" >38503.0054</td>
#       <td id="T_783e6_row2_col2" class="data row2 col2" >3324323213.7012</td>
#       <td id="T_783e6_row2_col3" class="data row2 col3" >54233.3227</td>
#       <td id="T_783e6_row2_col4" class="data row2 col4" >0.4079</td>
#       <td id="T_783e6_row2_col5" class="data row2 col5" >0.5841</td>
#       <td id="T_783e6_row2_col6" class="data row2 col6" >0.7098</td>
#       <td id="T_783e6_row2_col7" class="data row2 col7" >0.8940</td>
#     </tr>
#     <tr>
#       <th id="T_783e6_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_783e6_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_783e6_row3_col1" class="data row3 col1" >38503.8397</td>
#       <td id="T_783e6_row3_col2" class="data row3 col2" >3324302797.3219</td>
#       <td id="T_783e6_row3_col3" class="data row3 col3" >54233.3288</td>
#       <td id="T_783e6_row3_col4" class="data row3 col4" >0.4079</td>
#       <td id="T_783e6_row3_col5" class="data row3 col5" >0.5841</td>
#       <td id="T_783e6_row3_col6" class="data row3 col6" >0.7098</td>
#       <td id="T_783e6_row3_col7" class="data row3 col7" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_783e6_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_783e6_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_783e6_row4_col1" class="data row4 col1" >38503.0054</td>
#       <td id="T_783e6_row4_col2" class="data row4 col2" >3324323213.7012</td>
#       <td id="T_783e6_row4_col3" class="data row4 col3" >54233.3227</td>
#       <td id="T_783e6_row4_col4" class="data row4 col4" >0.4079</td>
#       <td id="T_783e6_row4_col5" class="data row4 col5" >0.5841</td>
#       <td id="T_783e6_row4_col6" class="data row4 col6" >0.7098</td>
#       <td id="T_783e6_row4_col7" class="data row4 col7" >0.0870</td>
#     </tr>
#     <tr>
#       <th id="T_783e6_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_783e6_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_783e6_row5_col1" class="data row5 col1" >38273.4195</td>
#       <td id="T_783e6_row5_col2" class="data row5 col2" >3223204760.1842</td>
#       <td id="T_783e6_row5_col3" class="data row5 col3" >54101.1578</td>
#       <td id="T_783e6_row5_col4" class="data row5 col4" >0.4059</td>
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best,data = test)

# %%
predictions
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               SE              FT  Machine Learning Scientist
# 1         2020               MI              FT           Lead Data Analyst
# 2         2020               MI              FT                Data Analyst
# 3         2020               MI              FT   Machine Learning Engineer
# 4         2020               MI              FT        Product Data Analyst
# ..         ...              ...             ...                         ...
# 102       2022               SE              FT                Data Analyst
# 103       2022               SE              FT              Data Architect
# 104       2022               SE              FT              Data Scientist
# 105       2022               EN              FT                Data Analyst
# 106       2022               SE              FT                Data Analyst
#
#     employee_residence  remote_ratio company_location company_size  \
# 0                   JP             0               JP            S
# 1                   US           100               US            L
# 2                   US           100               US            L
# 3                   CN             0               CN            M
# 4                   IN           100               IN            L
# ..                 ...           ...              ...          ...
# 102                 US           100               US            M
# 103                 US           100               US            M
# 104                 US           100               US            M
# 105                 CA             0               CA            M
# 106                 US             0               US            M
#
#      prediction_label
# 0        82075.340551
# 1       148086.947194
# 2       144086.950216
# 3       100711.621055
# 4        44339.691606
# ..                ...
# 102     142455.193758
# 103     157977.397943
# 104     146079.820033
# 105      50979.468396
# 106     136255.423559
#
# [107 rows x 9 columns]

# %%
solution1 = predictions.prediction_label

# %%
solution1 = pd.DataFrame(predictions.prediction_label)
solution1
# Out:
#      prediction_label
# 0        82075.340551
# 1       148086.947194
# 2       144086.950216
# 3       100711.621055
# 4        44339.691606
# ..                ...
# 102     142455.193758
# 103     157977.397943
# 104     146079.820033
# 105      50979.468396
# 106     136255.423559
#
# [107 rows x 1 columns]

# %%
solution1.reset_index(drop=True, inplace=True)

# %%
solution1
# Out:
#       id  salary_in_usd
# 0      0   82075.340551
# 1      1  148086.947194
# 2      2  144086.950216
# 3      3  100711.621055
# 4      4   44339.691606
# ..   ...            ...
# 102  102  142455.193758
# 103  103  157977.397943
# 104  104  146079.820033
# 105  105   50979.468396
# 106  106  136255.423559
#
# [107 rows x 2 columns]

# %%
solution1.rename(columns={"index": "id", 'prediction_label': "salary_in_usd"}, inplace= True)

# %%
solution1
# Out:
#       id  salary_in_usd
# 0      0   82075.340551
# 1      1  148086.947194
# 2      2  144086.950216
# 3      3  100711.621055
# 4      4   44339.691606
# ..   ...            ...
# 102  102  142455.193758
# 103  103  157977.397943
# 104  104  146079.820033
# 105  105   50979.468396
# 106  106  136255.423559
#
# [107 rows x 2 columns]

# %%
solution1.to_csv('sols/sol1.csv')

# %%
from sklearn.metrics import mean_squared_error as mse
mse(salaries, test, squared=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21768\2229856669.py in <module>
#       1 from sklearn.metrics import mean_squared_error as mse
# ----> 2 mse(salaries, test, squared=False)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [500, 107]
